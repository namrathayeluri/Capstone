# %% [markdown]
# ## Getting the data from ADLS

# %%
# Importing libraries
from pyspark.sql.functions import *
# Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setting the path to ADLS data
spark.conf.set(
    "fs.azure.account.key.capstoneadls1.dfs.core.windows.net", # capstoneadls1 - Storage account
    "JYwVSt9hWTJd87r7iQh7Gad1lxCkn7w3OVwK0GMxRMuQYwfYjqjhJzGctpdSZ+9kP3wCvZ5tbB79+ASthHzQHA==" # Security key of above storage account
)

# %%
#Reading the data from ADLS container that is created
df = spark.read.csv('abfss://capstonecontainer@capstoneadls1.dfs.core.windows.net/Capstone/main/bank_data.csv')
#capstonecontainer - Bronze layer container
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th><th>_c16</th><th>_c17</th></tr></thead><tbody><tr><td>1001</td><td>30</td><td>unemployed</td><td>married</td><td>primary</td><td>no</td><td>1787</td><td>no</td><td>no</td><td>cellular</td><td>19</td><td>oct</td><td>79</td><td>1</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1002</td><td>33</td><td>services</td><td>married</td><td>secondary</td><td>no</td><td>4789</td><td>yes</td><td>yes</td><td>cellular</td><td>11</td><td>may</td><td>220</td><td>1</td><td>339</td><td>4</td><td>failure</td><td>no</td></tr><tr><td>1003</td><td>35</td><td>management</td><td>single</td><td>tertiary</td><td>no</td><td>1350</td><td>yes</td><td>no</td><td>cellular</td><td>16</td><td>apr</td><td>185</td><td>1</td><td>330</td><td>1</td><td>failure</td><td>no</td></tr><tr><td>1004</td><td>30</td><td>management</td><td>married</td><td>tertiary</td><td>no</td><td>1476</td><td>yes</td><td>yes</td><td>unknown</td><td>3</td><td>jun</td><td>199</td><td>4</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1005</td><td>59</td><td>blue-collar</td><td>married</td><td>secondary</td><td>no</td><td>0</td><td>yes</td><td>no</td><td>unknown</td><td>5</td><td>may</td><td>226</td><td>1</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1006</td><td>35</td><td>management</td><td>single</td><td>tertiary</td><td>no</td><td>747</td><td>no</td><td>no</td><td>cellular</td><td>23</td><td>feb</td><td>141</td><td>2</td><td>176</td><td>3</td><td>failure</td><td>no</td></tr><tr><td>1007</td><td>36</td><td>self-employed</td><td>married</td><td>tertiary</td><td>no</td><td>307</td><td>yes</td><td>no</td><td>cellular</td><td>14</td><td>may</td><td>341</td><td>1</td><td>330</td><td>2</td><td>other</td><td>no</td></tr><tr><td>1008</td><td>39</td><td>technician</td><td>married</td><td>secondary</td><td>no</td><td>147</td><td>yes</td><td>no</td><td>cellular</td><td>6</td><td>may</td><td>151</td><td>2</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1009</td><td>41</td><td>entrepreneur</td><td>married</td><td>tertiary</td><td>no</td><td>221</td><td>yes</td><td>no</td><td>unknown</td><td>14</td><td>may</td><td>57</td><td>2</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1010</td><td>43</td><td>services</td><td>married</td><td>primary</td><td>no</td><td>-88</td><td>yes</td><td>yes</td><td>cellular</td><td>17</td><td>apr</td><td>313</td><td>1</td><td>147</td><td>2</td><td>failure</td><td>no</td></tr><tr><td>1011</td><td>39</td><td>services</td><td>married</td><td>secondary</td><td>no</td><td>9374</td><td>yes</td><td>no</td><td>unknown</td><td>20</td><td>may</td><td>273</td><td>1</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1012</td><td>43</td><td>admin.</td><td>married</td><td>secondary</td><td>no</td><td>264</td><td>yes</td><td>no</td><td>cellular</td><td>17</td><td>apr</td><td>113</td><td>2</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1013</td><td>36</td><td>technician</td><td>married</td><td>tertiary</td><td>no</td><td>1109</td><td>no</td><td>no</td><td>cellular</td><td>13</td><td>aug</td><td>328</td><td>2</td><td>-1</td><td>0</td><td>unknown</td><td>no</td></tr><tr><td>1014</td><td>20</td><td>student</td><td>single</td><td>secondary</td><td>no</td><td>502</td><td>no</td><td>no</td><td>cellular</td><td>30</td><td>apr</td><td>261</td><td>1</td><td>-1</td><td>0</td><td>unknown</td><td>yes</td></tr><tr><td>1015</td><td>31</td><td>blue-collar</td><td>married</td><td>secondary</td><td>no</td><td>360</td><td>yes</td><td>yes</td><td>cellular</td><td>29</td><td>jan</td><td>89</td><td>1</td><td>241</td><td>1</td><td>failure</td><td>no</td></tr><tr><td>1016</td><td>40</td><td ...

# %% [markdown]
# ## Defining headers for the existing dataset

# %%
# defining headers for dataset
headers = ["Unique_Sequence_ID", "age", "job","marital_status","education","credit_default","balance","housing","loan","contact","day","month","duration","campaign","pdays","previous","poutcome","opened_new_td_act_no_yes"]

# %%
# Assigning headers to dataframe
df1 = df.toDF(*headers)
df1.show()
# Out:
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|          job|marital_status|education|credit_default|balance|housing|loan| contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1001| 30|   unemployed|       married|  primary|            no|   1787|     no|  no|cellular| 19|  oct|      79|       1|   -1|       0| unknown|                      no|
# |              1002| 33|     services|       married|secondary|            no|   4789|    yes| yes|cellular| 11|  may|     220|       1|  339|       4| failure|                      no|
# |              1003| 35|   management|        single| tertiary|            no|   1350|    yes|  no|cellular| 16|  apr|     185|       1|  330|       1| failure|                      no|
# |              1004| 30|   management|       married| tertiary|            no|   1476|    yes| yes| unknown|  3|  jun|     199|       4|   -1|       0| unknown|                      no|
# |              1005| 59|  blue-collar|       married|secondary|            no|      0|    yes|  no| unknown|  5|  may|     226|       1|   -1|       0| unknown|                      no|
# |              1006| 35|   management|        single| tertiary|            no|    747|     no|  no|cellular| 23|  feb|     141|       2|  176|       3| failure|                      no|
# |              1007| 36|self-employed|       married| tertiary|            no|    307|    yes|  no|cellular| 14|  may|     341|       1|  330|       2|   other|                      no|
# |              1008| 39|   technician|       married|secondary|            no|    147|    yes|  no|cellular|  6|  may|     151|       2|   -1|       0| unknown|                      no|
# |              1009| 41| entrepreneur|       married| tertiary|            no|    221|    yes|  no| unknown| 14|  may|      57|       2|   -1|       0| unknown|                      no|
# |              1010| 43|     services|       married|  primary|            no|    -88|    yes| yes|cellular| 17|  apr|     313|       1|  147|       2| failure|                      no|
# |              1011| 39|     services|       married|secondary|            no|   9374|    yes|  no| unknown| 20|  may|     273|       1|   -1|       0| unknown|                      no|
# |              1012| 43|       admin.|       married|secondary|            no|    264|    yes|  no|cellular| 17|  apr|     113|       2|   -1|       0| unknown|                      no|
# |              1013| 36|   technician|       married| tertiary|            no|   1109|     no|  no|cellular| 13|  aug|     328|       2|   -1|       0| unknown|                      no|
# |              1014| 20|      student|        single|secondary|            no|    502|     no|  no|cellular| 30|  apr|     261|       1|   -1|       0| unknown|                     yes|
# |              1015| 31|  blue-collar|       married|secondary|            no|    360|    yes| yes|cellular| 29|  jan|      89|       1|  241|       1| failure|                      no|
# |              1016| 40|   management|       married| tertiary|            no|    194|     no| yes|cellular| 29|  aug|     189|       2|   -1|       0| unknown|                      no|
# |              1017| 56|   technician|       married|secondary|            no|   4073|     no|  no|cellular| 27|  aug|     239|       5|   -1|       0| unknown|                      no|
# |              1018| 37|       admin.|        single| tertiary|            no|   2317|    yes|  no|cellular| 20|  apr|     114|       1|  152|       2| failure|                      no|
# |              1019| 25|  blue-collar|        single|  primary|            no|   -221|    yes|  no| unknown| 23|  may|     250|       1|   -1|       0| unknown|                      no|
# |              1020| 31|     services|       married|secondary|            no|    132|     no|  no|cellular|  7|  jul|     148|       1|  152|       1|   other|                      no|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 20 rows

# %% [markdown]
# ### Verify Schema

# %%
#Verify Schema
df1.printSchema()
# Out:
# root
#  |-- Unique_Sequence_ID: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- credit_default: string (nullable = true)
#  |-- balance: string (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- campaign: string (nullable = true)
#  |-- pdays: string (nullable = true)
#  |-- previous: string (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- opened_new_td_act_no_yes: string (nullable = true)

# %%
#Checking the datatypes
df1.dtypes
# Out:
# Out[8]: [('Unique_Sequence_ID', 'string'),
#  ('age', 'string'),
#  ('job', 'string'),
#  ('marital_status', 'string'),
#  ('education', 'string'),
#  ('credit_default', 'string'),
#  ('balance', 'string'),
#  ('housing', 'string'),
#  ('loan', 'string'),
#  ('contact', 'string'),
#  ('day', 'string'),
#  ('month', 'string'),
#  ('duration', 'string'),
#  ('campaign', 'string'),
#  ('pdays', 'string'),
#  ('previous', 'string'),
#  ('poutcome', 'string'),
#  ('opened_new_td_act_no_yes', 'string')]

# %%
#Casting the datatypes
df = df1.withColumn("Unique_Sequence_ID", col("Unique_Sequence_ID").cast("integer")) \
    .withColumn("age", col("age").cast("integer")) \
    .withColumn("credit_default", col("credit_default").cast("boolean")) \
    .withColumn("balance", col("balance").cast("integer")) \
    .withColumn("housing", col("housing").cast("boolean")) \
    .withColumn("loan", col("loan").cast("boolean")) \
    .withColumn("day", col("day").cast("integer")) \
    .withColumn("duration", col("duration").cast("integer")) \
    .withColumn("campaign", col("campaign").cast("integer")) \
    .withColumn("pdays", col("pdays").cast("integer")) \
    .withColumn("previous", col("previous").cast("integer")) \
    .withColumn("opened_new_td_act_no_yes", col("opened_new_td_act_no_yes").cast("boolean"))

# %% [markdown]
# ## Verify Datatypes

# %%
df.dtypes
# Out:
# Out[10]: [('Unique_Sequence_ID', 'int'),
#  ('age', 'int'),
#  ('job', 'string'),
#  ('marital_status', 'string'),
#  ('education', 'string'),
#  ('credit_default', 'boolean'),
#  ('balance', 'int'),
#  ('housing', 'boolean'),
#  ('loan', 'boolean'),
#  ('contact', 'string'),
#  ('day', 'int'),
#  ('month', 'string'),
#  ('duration', 'int'),
#  ('campaign', 'int'),
#  ('pdays', 'int'),
#  ('previous', 'int'),
#  ('poutcome', 'string'),
#  ('opened_new_td_act_no_yes', 'boolean')]

# %% [markdown]
# ## Verify the schema

# %%
df.printSchema()
# Out:
# root
#  |-- Unique_Sequence_ID: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- credit_default: boolean (nullable = true)
#  |-- balance: integer (nullable = true)
#  |-- housing: boolean (nullable = true)
#  |-- loan: boolean (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- month: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- opened_new_td_act_no_yes: boolean (nullable = true)

# %% [markdown]
# ## Cache the dataframe

# %%
df.cache()
# Out:
# Out[12]: DataFrame[Unique_Sequence_ID: int, age: int, job: string, marital_status: string, education: string, credit_default: boolean, balance: int, housing: boolean, loan: boolean, contact: string, day: int, month: string, duration: int, campaign: int, pdays: int, previous: int, poutcome: string, opened_new_td_act_no_yes: boolean]

# %% [markdown]
# ## Verifying first few records

# %%
df.show(10)
# Out:
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|          job|marital_status|education|credit_default|balance|housing| loan| contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1001| 30|   unemployed|       married|  primary|         false|   1787|  false|false|cellular| 19|  oct|      79|       1|   -1|       0| unknown|                   false|
# |              1002| 33|     services|       married|secondary|         false|   4789|   true| true|cellular| 11|  may|     220|       1|  339|       4| failure|                   false|
# |              1003| 35|   management|        single| tertiary|         false|   1350|   true|false|cellular| 16|  apr|     185|       1|  330|       1| failure|                   false|
# |              1004| 30|   management|       married| tertiary|         false|   1476|   true| true| unknown|  3|  jun|     199|       4|   -1|       0| unknown|                   false|
# |              1005| 59|  blue-collar|       married|secondary|         false|      0|   true|false| unknown|  5|  may|     226|       1|   -1|       0| unknown|                   false|
# |              1006| 35|   management|        single| tertiary|         false|    747|  false|false|cellular| 23|  feb|     141|       2|  176|       3| failure|                   false|
# |              1007| 36|self-employed|       married| tertiary|         false|    307|   true|false|cellular| 14|  may|     341|       1|  330|       2|   other|                   false|
# |              1008| 39|   technician|       married|secondary|         false|    147|   true|false|cellular|  6|  may|     151|       2|   -1|       0| unknown|                   false|
# |              1009| 41| entrepreneur|       married| tertiary|         false|    221|   true|false| unknown| 14|  may|      57|       2|   -1|       0| unknown|                   false|
# |              1010| 43|     services|       married|  primary|         false|    -88|   true| true|cellular| 17|  apr|     313|       1|  147|       2| failure|                   false|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Verify the total number of rows and columns

# %%
print('Total number of rows in the dataframe is {} \n'.format(df.count()))
print("Total number of columns in the dataframe is {}".format(len(df.columns)))
# Out:
# Total number of rows in the dataframe is 4521
#
# Total number of columns in the dataframe is 18

# %% [markdown]
# ## Summary statistics

# %%
df.describe().show()
# Out:
# +-------+------------------+------------------+-------+--------------+---------+------------------+--------+------------------+-----+------------------+------------------+------------------+------------------+--------+
# |summary|Unique_Sequence_ID|               age|    job|marital_status|education|           balance| contact|               day|month|          duration|          campaign|             pdays|          previous|poutcome|
# +-------+------------------+------------------+-------+--------------+---------+------------------+--------+------------------+-----+------------------+------------------+------------------+------------------+--------+
# |  count|              4521|              4521|   4521|          4521|     4521|              4521|    4521|              4521| 4521|              4521|              4521|              4521|              4521|    4521|
# |   mean|            3261.0| 41.17009511170095|   null|          null|     null|1422.6578190665782|    null|15.915284229152842| null|263.96129174961294| 2.793629727936297|39.766644547666445|0.5425790754257908|    null|
# | stddev|1305.2446130898222|10.576210958711263|   null|          null|     null|3009.6381424673395|    null| 8.247667327229934| null|259.85663262468216|3.1098066601885823|100.12112444301656|1.6935623506071211|    null|
# |    min|              1001|                19| admin.|      divorced|  primary|             -3313|cellular|                 1|  apr|                 4|                 1|                -1|                 0| failure|
# |    max|              5521|                87|unknown|        single|  unknown|             71188| unknown|                31|  sep|              3025|                50|               871|                25| unknown|
# +-------+------------------+------------------+-------+--------------+---------+------------------+--------+------------------+-----+------------------+------------------+------------------+------------------+--------+

# %% [markdown]
# ##Find the maximum and minimum values in each column

# %%
max_values = df.agg(*[max(i).alias(f"max_{i}") for i in df.columns])
#agg() --> for Numarical column - highest value
#          for categorical column - highest repeated value
max_values.show()
# Out:
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+
# |max_Unique_Sequence_ID|max_age|max_job|max_marital_status|max_education|max_credit_default|max_balance|max_housing|max_loan|max_contact|max_day|max_month|max_duration|max_campaign|max_pdays|max_previous|max_poutcome|max_opened_new_td_act_no_yes|
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+
# |                  5521|     87|unknown|            single|      unknown|              true|      71188|       true|    true|    unknown|     31|      sep|        3025|          50|      871|          25|     unknown|                        true|
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+

# %%
min_values = df.agg(*[min(i).alias(f"min_{i}") for i in df.columns])
#agg() --> for Numarical column   - least value
#          for categorical column - least repeated value
min_values.show()
# Out:
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+
# |min_Unique_Sequence_ID|min_age|min_job|min_marital_status|min_education|min_credit_default|min_balance|min_housing|min_loan|min_contact|min_day|min_month|min_duration|min_campaign|min_pdays|min_previous|min_poutcome|min_opened_new_td_act_no_yes|
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+
# |                  1001|     19| admin.|          divorced|      primary|             false|      -3313|      false|   false|   cellular|      1|      apr|           4|           1|       -1|           0|     failure|                       false|
# +----------------------+-------+-------+------------------+-------------+------------------+-----------+-----------+--------+-----------+-------+---------+------------+------------+---------+------------+------------+----------------------------+

# %% [markdown]
# ##Find if there are any negative balances in the columns

# %%
neg_balances = df.filter(col("balance") < 0)# filtering the data for negative values in Balanace column
neg_balances.show()
# Out:
# +------------------+---+------------+--------------+---------+--------------+-------+-------+-----+---------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|         job|marital_status|education|credit_default|balance|housing| loan|  contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+------------+--------------+---------+--------------+-------+-------+-----+---------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1010| 43|    services|       married|  primary|         false|    -88|   true| true| cellular| 17|  apr|     313|       1|  147|       2| failure|                   false|
# |              1019| 25| blue-collar|        single|  primary|         false|   -221|   true|false|  unknown| 23|  may|     250|       1|   -1|       0| unknown|                   false|
# |              1049| 32|entrepreneur|        single|  primary|          true|   -849|   true| true| cellular|  4|  feb|     204|       1|   -1|       0| unknown|                   false|
# |              1061| 41| blue-collar|       married|  primary|         false|   -516|  false| true|telephone|  8|  jul|     554|       3|   -1|       0| unknown|                   false|
# |              1093| 27|    services|        single|secondary|         false|   -195|   true|false| cellular| 18|  may|     391|       1|   -1|       0| unknown|                    true|
# |              1124| 36| blue-collar|       married|secondary|         false|   -231|  false| true| cellular| 15|  jul|     779|       2|   -1|       0| unknown|                   false|
# |              1125| 51|  management|        single| tertiary|          true|    -55|   true|false| cellular| 11|  may|     281|       2|  266|       6| failure|                   false|
# |              1133| 43| blue-collar|       married|  unknown|          true|   -715|   true|false|  unknown| 30|  may|      67|       3|   -1|       0| unknown|                   false|
# |              1139| 52|  management|       married| tertiary|         false|   -970|   true|false| cellular|  4|  feb|     489|       1|   -1|       0| unknown|                    true|
# |              1153| 45|  unemployed|      divorced|  primary|          true|   -249|   true| true|  unknown|  1|  jul|      92|       1|   -1|       0| unknown|                   false|
# |              1163| 41|      admin.|        single|secondary|         false|   -256|  false| true|  unknown|  9|  may|      35|       3|   -1|       0| unknown|                   false|
# |              1176| 43|      admin.|       married|secondary|         false|   -465|   true| true| cellular| 23|  jul|     166|       1|   -1|       0| unknown|                   false|
# |              1185| 34|    services|       married|secondary|         false|    -62|   true|false|  unknown| 16|  jun|     109|       3|   -1|       0| unknown|                   false|
# |              1190| 56|     retired|       married|secondary|         false|  -1206|   true|false| cellular| 15|  jun|     382|       2|   -1|       0| unknown|                    true|
# |              1209| 38|    services|        single|secondary|         false|   -196|   true|false| cellular|  2|  feb|      60|       1|  271|       1| failure|                   false|
# |              1212| 25| blue-collar|        single|secondary|         false|   -350|   true|false|  unknown| 23|  jun|      95|       3|   -1|       0| unknown|                   false|
# |              1215| 31|  management|       married| tertiary|          true|   -253|  false|false| cellular| 12|  aug|     220|       4|   -1|       0| unknown|                   false|
# |              1221| 53|     retired|       married| tertiary|         false|    -22|   true|false| cellular| 31|  jul|      20|       3|   -1|       0| unknown|                   false|
# |              1227| 33|  technician|       married|secondary|         false|   -204|  false|false| cellular| 15|  may|     297|       3|   -1|       0| unknown|                   false|
# |              1244| 27|      admin.|       married|secondary|         false|   -247|   true| true|  unknown|  4|  jun|     344|       2|   -1|       0| unknown|                   false|
# +------------------+---+------------+--------------+---------+--------------+-------+-------+-----+---------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 20 rows

# %% [markdown]
# ##Replace the negative balances with zero.

# %%
#withColumn() is used to replace or add new column
replaced_negatives = df.withColumn("balance", when(col("balance") < 0, 0).otherwise(col("balance")))
# in this withColumn() is used to replace the existing column
replaced_negatives.show()
# Out:
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|          job|marital_status|education|credit_default|balance|housing| loan| contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1001| 30|   unemployed|       married|  primary|         false|   1787|  false|false|cellular| 19|  oct|      79|       1|   -1|       0| unknown|                   false|
# |              1002| 33|     services|       married|secondary|         false|   4789|   true| true|cellular| 11|  may|     220|       1|  339|       4| failure|                   false|
# |              1003| 35|   management|        single| tertiary|         false|   1350|   true|false|cellular| 16|  apr|     185|       1|  330|       1| failure|                   false|
# |              1004| 30|   management|       married| tertiary|         false|   1476|   true| true| unknown|  3|  jun|     199|       4|   -1|       0| unknown|                   false|
# |              1005| 59|  blue-collar|       married|secondary|         false|      0|   true|false| unknown|  5|  may|     226|       1|   -1|       0| unknown|                   false|
# |              1006| 35|   management|        single| tertiary|         false|    747|  false|false|cellular| 23|  feb|     141|       2|  176|       3| failure|                   false|
# |              1007| 36|self-employed|       married| tertiary|         false|    307|   true|false|cellular| 14|  may|     341|       1|  330|       2|   other|                   false|
# |              1008| 39|   technician|       married|secondary|         false|    147|   true|false|cellular|  6|  may|     151|       2|   -1|       0| unknown|                   false|
# |              1009| 41| entrepreneur|       married| tertiary|         false|    221|   true|false| unknown| 14|  may|      57|       2|   -1|       0| unknown|                   false|
# |              1010| 43|     services|       married|  primary|         false|      0|   true| true|cellular| 17|  apr|     313|       1|  147|       2| failure|                   false|
# |              1011| 39|     services|       married|secondary|         false|   9374|   true|false| unknown| 20|  may|     273|       1|   -1|       0| unknown|                   false|
# |              1012| 43|       admin.|       married|secondary|         false|    264|   true|false|cellular| 17|  apr|     113|       2|   -1|       0| unknown|                   false|
# |              1013| 36|   technician|       married| tertiary|         false|   1109|  false|false|cellular| 13|  aug|     328|       2|   -1|       0| unknown|                   false|
# |              1014| 20|      student|        single|secondary|         false|    502|  false|false|cellular| 30|  apr|     261|       1|   -1|       0| unknown|                    true|
# |              1015| 31|  blue-collar|       married|secondary|         false|    360|   true| true|cellular| 29|  jan|      89|       1|  241|       1| failure|                   false|
# |              1016| 40|   management|       married| tertiary|         false|    194|  false| true|cellular| 29|  aug|     189|       2|   -1|       0| unknown|                   false|
# |              1017| 56|   technician|       married|secondary|         false|   4073|  false|false|cellular| 27|  aug|     239|       5|   -1|       0| unknown|                   false|
# |              1018| 37|       admin.|        single| tertiary|         false|   2317|   true|false|cellular| 20|  apr|     114|       1|  152|       2| failure|                   false|
# |              1019| 25|  blue-collar|        single|  primary|         false|      0|   true|false| unknown| 23|  may|     250|       1|   -1|       0| unknown|                   false|
# |              1020| 31|     services|       married|secondary|         false|    132|  false|false|cellular|  7|  jul|     148|       1|  152|       1|   other|                   false|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Created a view in Spark Dataframe

# %%
#Created a view in the spark dataframe to run sql queries on the dataframe.
df.createOrReplaceTempView("dfview")

df.show(5)
# Out:
# +------------------+---+-----------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|        job|marital_status|education|credit_default|balance|housing| loan| contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+-----------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1001| 30| unemployed|       married|  primary|         false|   1787|  false|false|cellular| 19|  oct|      79|       1|   -1|       0| unknown|                   false|
# |              1002| 33|   services|       married|secondary|         false|   4789|   true| true|cellular| 11|  may|     220|       1|  339|       4| failure|                   false|
# |              1003| 35| management|        single| tertiary|         false|   1350|   true|false|cellular| 16|  apr|     185|       1|  330|       1| failure|                   false|
# |              1004| 30| management|       married| tertiary|         false|   1476|   true| true| unknown|  3|  jun|     199|       4|   -1|       0| unknown|                   false|
# |              1005| 59|blue-collar|       married|secondary|         false|      0|   true|false| unknown|  5|  may|     226|       1|   -1|       0| unknown|                   false|
# +------------------+---+-----------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 5 rows

# %% [markdown]
# ##Verify the target distribution.

# %%
#Verify the target distribution.
spark.sql("SELECT opened_new_td_act_no_yes FROM dfview Limit 15").show()
# Out:
# +------------------------+
# |opened_new_td_act_no_yes|
# +------------------------+
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                   false|
# |                    true|
# |                   false|
# +------------------------+

# %% [markdown]
# ##Find the pairwise frequency between target and loan columns

# %%
#Using crosstab() to create pairwise frequency between target and loan columns
df.crosstab('opened_new_td_act_no_yes', 'loan').show()
# Out:
# +-----------------------------+-----+----+
# |opened_new_td_act_no_yes_loan|false|true|
# +-----------------------------+-----+----+
# |                        false| 3352| 648|
# |                         true|  478|  43|
# +-----------------------------+-----+----+

# %%
df.groupBy('opened_new_td_act_no_yes', 'loan').count().show()
# Out:
# +------------------------+-----+-----+
# |opened_new_td_act_no_yes| loan|count|
# +------------------------+-----+-----+
# |                    true|false|  478|
# |                    true| true|   43|
# |                   false|false| 3352|
# |                   false| true|  648|
# +------------------------+-----+-----+

# %% [markdown]
# ##Find the term deposit not-opted for different job categories.

# %%
df.crosstab('opened_new_td_act_no_yes', 'job').show()
# Out:
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |opened_new_td_act_no_yes_job|admin.|blue-collar|entrepreneur|housemaid|management|retired|self-employed|services|student|technician|unemployed|unknown|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |                       false|   420|        877|         153|       98|       838|    176|          163|     379|     65|       685|       115|     31|
# |                        true|    58|         69|          15|       14|       131|     54|           20|      38|     19|        83|        13|      7|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+

# %% [markdown]
# ##Term deposit opted for different job categories.

# %%
term_opted = df.filter(col("opened_new_td_act_no_yes")=='True')
final_term_opted=term_opted.crosstab('opened_new_td_act_no_yes', 'job')
final_term_opted.show()
# Out:
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |opened_new_td_act_no_yes_job|admin.|blue-collar|entrepreneur|housemaid|management|retired|self-employed|services|student|technician|unemployed|unknown|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |                        true|    58|         69|          15|       14|       131|     54|           20|      38|     19|        83|        13|      7|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+

# %%
# Plotting Bargraph for above data
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = term_opted.toPandas()

# Plot a bar chart
pandas_df.groupby(['job', 'opened_new_td_act_no_yes']).size().unstack().plot(kind='bar')

# Display the plot
plt.show()

# %% [markdown]
# ##Term deposit not opted for different job categories.

# %%
term_not_opted = df.filter(col("opened_new_td_act_no_yes")=='False')
term_not_opted.crosstab('opened_new_td_act_no_yes', 'job').show()
# Out:
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |opened_new_td_act_no_yes_job|admin.|blue-collar|entrepreneur|housemaid|management|retired|self-employed|services|student|technician|unemployed|unknown|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+
# |                       false|   420|        877|         153|       98|       838|    176|          163|     379|     65|       685|       115|     31|
# +----------------------------+------+-----------+------------+---------+----------+-------+-------------+--------+-------+----------+----------+-------+

# %%
# Ploting Bargraph for above data
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = term_not_opted.toPandas()

# Plot a bar chart
pandas_df.groupby(['job', 'opened_new_td_act_no_yes']).size().unstack().plot(kind='bar')

# Display the plot
plt.show()

# %% [markdown]
# ##Term deposit not opted for different education categories.

# %%
term_not_opted_edu = df.filter(col("opened_new_td_act_no_yes")=='False')
term_not_opted_edu.crosstab('opened_new_td_act_no_yes', 'education').show()
# Out:
# +----------------------------------+-------+---------+--------+-------+
# |opened_new_td_act_no_yes_education|primary|secondary|tertiary|unknown|
# +----------------------------------+-------+---------+--------+-------+
# |                             false|    614|     2061|    1157|    168|
# +----------------------------------+-------+---------+--------+-------+

# %%
# Ploting Bargraph for above data
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = term_not_opted_edu.toPandas()

# Plot a bar chart
pandas_df.groupby(['education', 'opened_new_td_act_no_yes']).size().unstack().plot(kind='bar')

# Display the plot
plt.show()

# %% [markdown]
# ##Term deposit not opted for different marital status categories.

# %%
term_not_opted_marital = df.filter(col("opened_new_td_act_no_yes")=='False')
term_not_opted_marital.crosstab('opened_new_td_act_no_yes', 'marital_status').show()
# Out:
# +---------------------------------------+--------+-------+------+
# |opened_new_td_act_no_yes_marital_status|divorced|married|single|
# +---------------------------------------+--------+-------+------+
# |                                  false|     451|   2520|  1029|
# +---------------------------------------+--------+-------+------+

# %%
# Ploting Bargraph for above data
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = term_not_opted_marital.toPandas()

# Plot a bar chart
pandas_df.groupby(['marital_status', 'opened_new_td_act_no_yes']).size().unstack().plot(kind='bar')

# Display the plot
plt.show()

# %% [markdown]
# ##Plot a heat map for the dataframe

# %%
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = df.toPandas()

# Plot a heat map
plt.figure(figsize=(10, 10))  # Set the size of the plot

sns.heatmap(pandas_df.corr(), annot=True, cmap="YlGnBu")  # Use the correlation matrix as input for the heat map

# Display the plot
plt.show()

# %% [markdown]
# ##Remove null values in the dataframe

# %%
null_removed = df.na.drop()
null_removed.show()
# Out:
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |Unique_Sequence_ID|age|          job|marital_status|education|credit_default|balance|housing| loan| contact|day|month|duration|campaign|pdays|previous|poutcome|opened_new_td_act_no_yes|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# |              1001| 30|   unemployed|       married|  primary|         false|   1787|  false|false|cellular| 19|  oct|      79|       1|   -1|       0| unknown|                   false|
# |              1002| 33|     services|       married|secondary|         false|   4789|   true| true|cellular| 11|  may|     220|       1|  339|       4| failure|                   false|
# |              1003| 35|   management|        single| tertiary|         false|   1350|   true|false|cellular| 16|  apr|     185|       1|  330|       1| failure|                   false|
# |              1004| 30|   management|       married| tertiary|         false|   1476|   true| true| unknown|  3|  jun|     199|       4|   -1|       0| unknown|                   false|
# |              1005| 59|  blue-collar|       married|secondary|         false|      0|   true|false| unknown|  5|  may|     226|       1|   -1|       0| unknown|                   false|
# |              1006| 35|   management|        single| tertiary|         false|    747|  false|false|cellular| 23|  feb|     141|       2|  176|       3| failure|                   false|
# |              1007| 36|self-employed|       married| tertiary|         false|    307|   true|false|cellular| 14|  may|     341|       1|  330|       2|   other|                   false|
# |              1008| 39|   technician|       married|secondary|         false|    147|   true|false|cellular|  6|  may|     151|       2|   -1|       0| unknown|                   false|
# |              1009| 41| entrepreneur|       married| tertiary|         false|    221|   true|false| unknown| 14|  may|      57|       2|   -1|       0| unknown|                   false|
# |              1010| 43|     services|       married|  primary|         false|    -88|   true| true|cellular| 17|  apr|     313|       1|  147|       2| failure|                   false|
# |              1011| 39|     services|       married|secondary|         false|   9374|   true|false| unknown| 20|  may|     273|       1|   -1|       0| unknown|                   false|
# |              1012| 43|       admin.|       married|secondary|         false|    264|   true|false|cellular| 17|  apr|     113|       2|   -1|       0| unknown|                   false|
# |              1013| 36|   technician|       married| tertiary|         false|   1109|  false|false|cellular| 13|  aug|     328|       2|   -1|       0| unknown|                   false|
# |              1014| 20|      student|        single|secondary|         false|    502|  false|false|cellular| 30|  apr|     261|       1|   -1|       0| unknown|                    true|
# |              1015| 31|  blue-collar|       married|secondary|         false|    360|   true| true|cellular| 29|  jan|      89|       1|  241|       1| failure|                   false|
# |              1016| 40|   management|       married| tertiary|         false|    194|  false| true|cellular| 29|  aug|     189|       2|   -1|       0| unknown|                   false|
# |              1017| 56|   technician|       married|secondary|         false|   4073|  false|false|cellular| 27|  aug|     239|       5|   -1|       0| unknown|                   false|
# |              1018| 37|       admin.|        single| tertiary|         false|   2317|   true|false|cellular| 20|  apr|     114|       1|  152|       2| failure|                   false|
# |              1019| 25|  blue-collar|        single|  primary|         false|   -221|   true|false| unknown| 23|  may|     250|       1|   -1|       0| unknown|                   false|
# |              1020| 31|     services|       married|secondary|         false|    132|  false|false|cellular|  7|  jul|     148|       1|  152|       1|   other|                   false|
# +------------------+---+-------------+--------------+---------+--------------+-------+-------+-----+--------+---+-----+--------+--------+-----+--------+--------+------------------------+
# only showing top 20 rows

# %% [markdown]
# ##Split the data into training and testing

# %%
training_data, testing_data = df.randomSplit([0.8, 0.2], seed=234) #randomSplit() splits the data randomly base on given weights
print("count of Training data: " + str(training_data.count()))
print("count of Testing data: " + str(testing_data.count()))
# Out:
# count of Training data: 3584
# count of Testing data: 937

# %% [markdown]
# ## Writing the Transformed data into Gold layer

# %%
spark.conf.set(
    "fs.azure.account.key.goldlayer.dfs.core.windows.net",
    "uLUZLUgaEIjWYXJqa+x3xbnqYoI8FSJMzaPiRaTUP4LVVRK/eciYrO/rDXBIT1NL7Rub5HcwRzcg+AStTRriUQ=="
)

# %%
# Define the output path in ADLS Gold layer
output_path = "abfss://goldlayeradls@goldlayer.dfs.core.windows.net/"

# Write the DataFrame to ADLS
df.write.format("delta").save(output_path)
